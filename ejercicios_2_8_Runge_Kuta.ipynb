# %% [markdown]
# <a href="https://colab.research.google.com/github/janorena/modelado-y-simulacion/blob/master/ejercicios_2_8_Runge_Kuta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Jorge Andrés Noreña García - 816543
#
# # ejercicios 2.8 - Runge Kutta

# %%
import matplotlib.style
matplotlib.style.use('classic')
import numpy as np
from matplotlib import pyplot as plt
from scipy.integrate import solve_ivp

# %%
#Definimos el método de Runge Kutta de cuarto orden

def rk4( func, h, tini, tfin, x0, params ):
    ti = tini  
    xi = x0
  
    x = list()
    t = list()
  
    while ( ti < tfin ):

      x.append (xi)
      t.append (ti)
      k1 = func( ti,xi,params)
      k2 = func( ti + 0.5*h,xi + 0.5*k1*h,params )
      k3 = func( ti + 0.5*h,xi + 0.5*k2*h,params)
      k4 = func( ti + h,xi + k3*h,params) 

      xi = xi + h*(k1 + 2*k2 + 2*k3 + k4)/6
      ti = ti + h
    return t, x

# Definimos el método de Euler 

def euler( func, h, tini, tfin, x0, params ):
    ti = tini  
    xi = x0
  
    x = list()
    t = list()
  
    while ( ti < tfin ):
    
      x.append (xi)
      t.append (ti)
  
      xi = xi + h*func(ti,xi,params)
      ti = ti + h
    return t, x

# %% [markdown]
# # 2.8.2-a)   $\dot { x } = x$

# %%
def sistema1(t, x, a):
    x_dot = a*x
    return x_dot

# %%
a = 1
h = 0.01
ti = 0
tf = 10
x0 = 0.8

plt.figure(figsize=(10, 5), dpi=100)
for i in range(0,15,1):
    x0=i
    t1,x1 = euler( sistema1, h, ti, tf, x0 ,a )
    t2,x2 = rk4( sistema1, h, ti, tf, x0 ,a)
    if i==0:
      plt.plot( t1, x1, c = 'crimson', label = 'Euler', linewidth = 2)
      plt.plot( t2, x2, c = 'royalblue', label = 'RK4', linewidth = 2)
    else:
      plt.plot( t1, x1, c = 'crimson', linewidth = 2)
      plt.plot( t2, x2, c = 'royalblue', linewidth = 2)


plt.xlim([0, tf])
plt.xlabel(r'$t$')
plt.grid()
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# # 2.8.2-b)   $\dot { x } = 1-x^2$

# %%
def sistema2(t, x, a):
    x_dot = 1-x**2
    return x_dot

# %%
a = 1
h = 0.01
ti = 0
tf = 10
x0 = 0.8

plt.figure(figsize=(10, 5), dpi=100)
for i in range(0,15,1):
    x0=i
    t1,x1 = euler( sistema2, h, ti, tf, x0 ,a )
    t2,x2 = rk4( sistema2, h, ti, tf, x0 ,a)
    if i==0:
      plt.plot( t1, x1, c = 'crimson', label = 'Euler', linewidth = 2)
      plt.plot( t2, x2, c = 'royalblue', label = 'RK4', linewidth = 2)
    else:
      plt.plot( t1, x1, c = 'crimson', linewidth = 2)
      plt.plot( t2, x2, c = 'royalblue', linewidth = 2)


plt.xlim([0, tf])
plt.xlabel(r'$t$')
plt.grid()
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# # 2.8.2-c)   $\dot { x } = 1-4x(1-x)$

# %%
def sistema3(t, x, a):
    x_dot = 1-4*x*(1-x)
    return x_dot

# %%
a = 1
h = 0.1
ti = 0
tf = 1
x0 = 0

plt.figure(figsize=(10, 5), dpi=100)
for i in range(-10,30,1):
    x0=i
    t1,x1 = euler( sistema3, h, ti, tf, x0 ,a )
    t2,x2 = rk4( sistema3, h, ti, tf, x0 ,a)
    if i==0:
      plt.plot( t1, x1, c = 'crimson', label = 'Euler', linewidth = 2)
      plt.plot( t2, x2, c = 'royalblue', label = 'RK4', linewidth = 2)
    else:
      plt.plot( t1, x1, c = 'crimson', linewidth = 2)
      plt.plot( t2, x2, c = 'royalblue', linewidth = 2)


plt.xlim([0, tf])
plt.xlabel(r'$t$')
plt.grid()
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# # 2.8.2-d)   $\dot { x } = sin(x)$

# %%
def sistema4(t, x, a):
    x_dot = np.sin(x)
    return x_dot

# %%
a = 1
h = 0.01
ti = 0
tf = 10
x0 = 0.8

plt.figure(figsize=(10, 5), dpi=100)
for i in range(0,15,1):
    x0=i
    t1,x1 = euler( sistema4, h, ti, tf, x0 ,a )
    t2,x2 = rk4( sistema4, h, ti, tf, x0 ,a)
    if i==0:
      plt.plot( t1, x1, c = 'crimson', label = 'Euler', linewidth = 2)
      plt.plot( t2, x2, c = 'royalblue', label = 'RK4', linewidth = 2)
    else:
      plt.plot( t1, x1, c = 'crimson', linewidth = 2)
      plt.plot( t2, x2, c = 'royalblue', linewidth = 2)


plt.xlim([0, tf])
plt.xlabel(r'$t$')
plt.grid()
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ## 2.8.3-a) $\dot { x } = -x$ , $ x(0)=1 $

# %%
def sistema5(t, x, a):
    x_dot = -x
    return x_dot

# %%
a = 1
h = 0.01
ti = 0
tf = 10
x0 = 1

plt.figure(figsize=(10, 5), dpi=100)
for i in range(0,15,1):
    x0=i
    t1,x1 = euler( sistema5, h, ti, tf, x0 ,a )
    t2,x2 = rk4( sistema5, h, ti, tf, x0 ,a)
    if i==0:
      plt.plot( t1, x1, c = 'crimson', label = 'Euler', linewidth = 2)
      plt.plot( t2, x2, c = 'royalblue', label = 'RK4', linewidth = 2)
    else:
      plt.plot( t1, x1, c = 'crimson', linewidth = 2)
      plt.plot( t2, x2, c = 'royalblue', linewidth = 2)


plt.xlim([0, tf])
plt.xlabel(r'$t$')
plt.grid()
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ## 2.8.3-b)

# %%
a = 1
h = 0.01
ti = 0
tf = 1
x0 = 1

plt.figure(figsize=(10, 5), dpi=100)
for i in range(0,15,1):
    x0=i
    t1,x1 = euler( sistema5, h, ti, tf, x0 ,a )
    t2,x2 = rk4( sistema5, h, ti, tf, x0 ,a)
    if i==0:
      plt.plot( t1, x1, c = 'crimson', label = 'Euler', linewidth = 2)
      plt.plot( t2, x2, c = 'royalblue', label = 'RK4', linewidth = 2)
    else:
      plt.plot( t1, x1, c = 'crimson', linewidth = 2)
      plt.plot( t2, x2, c = 'royalblue', linewidth = 2)


plt.xlim([0, tf])
plt.xlabel(r'$t$')
plt.grid()
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ## 2.8.3-c)
